# %%
# Basic Libraries
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt # we only need pyplot
sb.set() # set the default Seaborn style for graphics

# Import essential models and functions from sklearn
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.metrics import explained_variance_score, mean_squared_error

# %%
# Importing the new CSV file
Report = pd.read_csv('final_version_dataset.csv')
Report.head()
# Out:
#    HAPPINESS_SCORE  GDP_PER_CAPITA    FAMILY  LIFE_EXPECTANCY   FREEDOM  \
# 0            7.537        1.616463  1.533524         0.796667  0.635423
# 1            7.522        1.482383  1.551122         0.792566  0.626007
# 2            7.504        1.480633  1.610574         0.833552  0.627163
# 3            7.494        1.564980  1.516912         0.858131  0.620071
# 4            7.469        1.443572  1.540247         0.809158  0.617951
#
#    GENEROSITY  GOVERNMENT_TRUST  DYSTOPIA_RESIDUAL  SOCIAL_SUPPORT
# 0    0.362012          0.315964           2.277027        1.367063
# 1    0.355280          0.400770           2.313707        1.323532
# 2    0.475540          0.153527           2.322715        1.384824
# 3    0.290549          0.367007           2.276716        1.349466
# 4    0.245483          0.382612           2.430182        1.315484

# %% [markdown]
# ## Linear Regression (GDP_PER_CAPITA)

# %%
# Mean Squared Error (MSE)
def mean_sq_err(actual, predicted):
    '''Returns the Mean Squared Error of actual and predicted values'''
    return np.mean(np.square(np.array(actual) - np.array(predicted)))

# %%
# Define the DataFrame for Happiness Score and GDP per Capita
Happiness_Score = pd.DataFrame(Report['HAPPINESS_SCORE']) #Response
GDP = pd.DataFrame(Report['GDP_PER_CAPITA']) #Predictor

# Split the Dataset into Train and Test
X_train, X_test, y_train, y_test = train_test_split(GDP, Happiness_Score, test_size = 0.25)

# Linear Regression using Train Data
linreg = LinearRegression()         # create the linear regression object
linreg.fit(X_train, y_train)        # train the linear regression model

# Coefficients of the Linear Regression line
print('Intercept of Regression \t: b = ', linreg.intercept_)
print('Coefficients of Regression \t: a = ', linreg.coef_)
print()

# Predict Happiness Score corresponding to GDP per capita
y_train_pred = linreg.predict(X_train)
y_test_pred = linreg.predict(X_test)

# Formula for the Regression line
regline_x = X_train
regline_y = linreg.intercept_ + linreg.coef_ * X_train

#Plotting the scatterplot of data points
f = plt.figure(figsize=(16, 8))
plt.scatter(X_train, y_train)
plt.scatter(X_train, y_train_pred, color = "r")
plt.show()

# Check the Goodness of Fit (on Train Data)
print("Goodness of Fit of Model \tTrain Dataset")
print("Explained Variance (R^2) \t: {:.4f}".format(linreg.score(X_train, y_train)))
mse_train = mean_sq_err(y_train, y_train_pred)
print("Mean Squared Error (MSE) \t: {:.4f}".format(mse_train))
print("Root Mean Squared Error (RMSE) \t: {:.4f}".format(np.sqrt(mse_train)))
print()

# Check the Goodness of Fit (on Test Data)
print("Goodness of Fit of Model \tTest Dataset")
print("Explained Variance (R^2) \t: {:.4f}".format(linreg.score(X_test, y_test)))
mse_test = mean_sq_err(y_test, y_test_pred)
print("Mean Squared Error (MSE) \t: {:.4f}".format(mse_test))
print("Root Mean Squared Error (RMSE) \t: {:.4f}".format(np.sqrt(mse_test)))
print()

# Plot Linear Regression Line for test dataset
f = plt.figure(figsize=(16, 8))
plt.scatter(X_test, y_test, color = "green")
plt.scatter(X_test, y_test_pred, color = "red")
plt.show()
# Out:
# Intercept of Regression 	: b =  [3.35358756]
# Coefficients of Regression 	: a =  [[2.28280583]]
# Goodness of Fit of Model 	Train Dataset
# Explained Variance (R^2) 	: 0.6343
# Mean Squared Error (MSE) 	: 0.4651
# Root Mean Squared Error (RMSE) 	: 0.6820
#
# Goodness of Fit of Model 	Test Dataset
# Explained Variance (R^2) 	: 0.6181
# Mean Squared Error (MSE) 	: 0.4557
# Root Mean Squared Error (RMSE) 	: 0.6751

# %% [markdown]
# ## Linear Regression (SOCIAL_SUPPORT)

# %%
# Define the DataFrame for Happiness Score and Social Support
Happiness_Score = pd.DataFrame(Report['HAPPINESS_SCORE']) #Response
Social_Support = pd.DataFrame(Report['SOCIAL_SUPPORT']) #Predictor

# Split the Dataset into Train and Test
X_train, X_test, y_train, y_test = train_test_split(Social_Support, Happiness_Score, test_size = 0.25)

# Linear Regression using Train Data
linreg = LinearRegression()         # create the linear regression object
linreg.fit(X_train, y_train)        # train the linear regression model

# Coefficients of the Linear Regression line
print('Intercept of Regression \t: b = ', linreg.intercept_)
print('Coefficients of Regression \t: a = ', linreg.coef_)
print()

# Predict Happiness scores corresponding to Social Support
y_train_pred = linreg.predict(X_train)
y_test_pred = linreg.predict(X_test)

# Formula for the Regression line
regline_x = X_train
regline_y = linreg.intercept_ + linreg.coef_ * X_train

#Plotting the scatterplot of data points
f = plt.figure(figsize=(16, 8))
plt.scatter(X_train, y_train)
plt.scatter(X_train, y_train_pred, color = "r")
plt.show()

# Check the Goodness of Fit (on Train Data)
print("Goodness of Fit of Model \tTrain Dataset")
print("Explained Variance (R^2) \t: {:.4f}".format(linreg.score(X_train, y_train)))
mse_train = mean_sq_err(y_train, y_train_pred)
print("Mean Squared Error (MSE) \t: {:.4f}".format(mse_train))
print("Root Mean Squared Error (RMSE) \t: {:.4f}".format(np.sqrt(mse_train)))
print()

# Check the Goodness of Fit (on Test Data)
print("Goodness of Fit of Model \tTest Dataset")
print("Explained Variance (R^2) \t: {:.4f}".format(linreg.score(X_test, y_test)))
mse_test = mean_sq_err(y_test, y_test_pred)
print("Mean Squared Error (MSE) \t: {:.4f}".format(mse_test))
print("Root Mean Squared Error (RMSE) \t: {:.4f}".format(np.sqrt(mse_test)))
print()

# Plot Linear Regression Line for test dataset
f = plt.figure(figsize=(16, 8))
plt.scatter(X_test, y_test, color = "green")
plt.scatter(X_test, y_test_pred, color = "red")
plt.show()
# Out:
# Intercept of Regression 	: b =  [1.06430107]
# Coefficients of Regression 	: a =  [[3.64895538]]
# Goodness of Fit of Model 	Train Dataset
# Explained Variance (R^2) 	: 0.4835
# Mean Squared Error (MSE) 	: 0.6553
# Root Mean Squared Error (RMSE) 	: 0.8095
#
# Goodness of Fit of Model 	Test Dataset
# Explained Variance (R^2) 	: 0.5201
# Mean Squared Error (MSE) 	: 0.5724
# Root Mean Squared Error (RMSE) 	: 0.7566

# %% [markdown]
# ## Linear Regression (LIFE_EXPECTANCY)

# %%
# Define the DataFrame for Happiness Score and Life Expectancy
Happiness_Score = pd.DataFrame(Report['HAPPINESS_SCORE']) #Response
Life_Expectancy = pd.DataFrame(Report['LIFE_EXPECTANCY']) #Predictor

# Split the Dataset into Train and Test
X_train, X_test, y_train, y_test = train_test_split(Life_Expectancy, Happiness_Score, test_size = 0.25)

# Linear Regression using Train Data
linreg = LinearRegression()         # create the linear regression object
linreg.fit(X_train, y_train)        # train the linear regression model

# Coefficients of the Linear Regression line
print('Intercept of Regression \t: b = ', linreg.intercept_)
print('Coefficients of Regression \t: a = ', linreg.coef_)
print()

# Predict Happiness Scores corresponding to Life Expectancy
y_train_pred = linreg.predict(X_train)
y_test_pred = linreg.predict(X_test)

# Formula for the Regression line
regline_x = X_train
regline_y = linreg.intercept_ + linreg.coef_ * X_train

#Plotting the scatterplot of data points
f = plt.figure(figsize=(16, 8))
plt.scatter(X_train, y_train)
plt.scatter(X_train, y_train_pred, color = "r")
plt.show()

# Check the Goodness of Fit (on Train Data)
print("Goodness of Fit of Model \tTrain Dataset")
print("Explained Variance (R^2) \t: {:.4f}".format(linreg.score(X_train, y_train)))
mse_train = mean_sq_err(y_train, y_train_pred)
print("Mean Squared Error (MSE) \t: {:.4f}".format(mse_train))
print("Root Mean Squared Error (RMSE) \t: {:.4f}".format(np.sqrt(mse_train)))
print()

# Check the Goodness of Fit (on Test Data)
print("Goodness of Fit of Model \tTest Dataset")
print("Explained Variance (R^2) \t: {:.4f}".format(linreg.score(X_test, y_test)))
mse_test = mean_sq_err(y_test, y_test_pred)
print("Mean Squared Error (MSE) \t: {:.4f}".format(mse_test))
print("Root Mean Squared Error (RMSE) \t: {:.4f}".format(np.sqrt(mse_test)))
print()

# Plot Linear Regression Line for test dataset
f = plt.figure(figsize=(16, 8))
plt.scatter(X_test, y_test, color = "green")
plt.scatter(X_test, y_test_pred, color = "red")
plt.show()
# Out:
# Intercept of Regression 	: b =  [3.26867152]
# Coefficients of Regression 	: a =  [[3.43930541]]
# Goodness of Fit of Model 	Train Dataset
# Explained Variance (R^2) 	: 0.5605
# Mean Squared Error (MSE) 	: 0.5324
# Root Mean Squared Error (RMSE) 	: 0.7297
#
# Goodness of Fit of Model 	Test Dataset
# Explained Variance (R^2) 	: 0.5833
# Mean Squared Error (MSE) 	: 0.5724
# Root Mean Squared Error (RMSE) 	: 0.7566

# %% [markdown]
# ## Multi-variate Linear Regression

# %%
# Extract Response and Predictors
Happiness_Score = pd.DataFrame(Report["HAPPINESS_SCORE"]) #Response
Predictors = pd.DataFrame(Report[["GDP_PER_CAPITA", "SOCIAL_SUPPORT", "LIFE_EXPECTANCY"]]) #Predictor

# Split the Dataset into Train and Test
X_train, X_test, y_train, y_test = train_test_split(Predictors, Happiness_Score, test_size = 0.25)

# Linear Regression using Train Data
linreg = LinearRegression()         # create the linear regression object
linreg.fit(X_train, y_train)        # train the linear regression model

# Coefficients of the Linear Regression line
print('Intercept of Regression \t: b = ', linreg.intercept_)
print('Coefficients of Regression \t: a = ', linreg.coef_)
print()

# Print the Coefficients against Predictors
print(pd.DataFrame(list(zip(X_train.columns, linreg.coef_[0])), columns = ["Predictors", "Coefficients"]))
print()

# Predict Response corresponding to Predictors
y_train_pred = linreg.predict(X_train)
y_test_pred = linreg.predict(X_test)

# Plot the Predictions vs the True values
f, axes = plt.subplots(1, 2, figsize=(24, 12))
axes[0].scatter(y_train, y_train_pred, color = "blue")
axes[0].set_xlabel("True values of the Response Variable (Train)")
axes[0].set_ylabel("Predicted values of the Response Variable (Train)")
axes[1].scatter(y_test, y_test_pred, color = "green")
axes[1].set_xlabel("True values of the Response Variable (Test)")
axes[1].set_ylabel("Predicted values of the Response Variable (Test)")
plt.show()

# Check the Goodness of Fit (on Train Data)
print("Goodness of Fit of Model \tTrain Dataset")
print("Explained Variance (R^2) \t: {:.4f}".format(linreg.score(X_train, y_train)))
mse_train = mean_sq_err(y_train, y_train_pred)
print("Mean Squared Error (MSE) \t: {:.4f}".format(mse_train))
print("Root Mean Squared Error (RMSE) \t: {:.4f}".format(np.sqrt(mse_train)))
print()

# Check the Goodness of Fit (on Test Data)
print("Goodness of Fit of Model \tTest Dataset")
print("Explained Variance (R^2) \t: {:.4f}".format(linreg.score(X_test, y_test)))
mse_test = mean_sq_err(y_test, y_test_pred)
print("Mean Squared Error (MSE) \t: {:.4f}".format(mse_test))
print("Root Mean Squared Error (RMSE) \t: {:.4f}".format(np.sqrt(mse_test)))
print()
# Out:
# Intercept of Regression 	: b =  [2.20109458]
# Coefficients of Regression 	: a =  [[1.17516973 1.07478113 1.37394649]]
#
#         Predictors  Coefficients
# 0   GDP_PER_CAPITA      1.175170
# 1   SOCIAL_SUPPORT      1.074781
# 2  LIFE_EXPECTANCY      1.373946
# Goodness of Fit of Model 	Train Dataset
# Explained Variance (R^2) 	: 0.6995
# Mean Squared Error (MSE) 	: 0.3711
# Root Mean Squared Error (RMSE) 	: 0.6091
#
# Goodness of Fit of Model 	Test Dataset
# Explained Variance (R^2) 	: 0.6962
# Mean Squared Error (MSE) 	: 0.3955
# Root Mean Squared Error (RMSE) 	: 0.6289
